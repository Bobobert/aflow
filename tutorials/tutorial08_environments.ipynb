# %% [markdown]
# # Tutorial 08: Creating Custom Environments
#
# This tutorial walks you through the process of creating custom environments in Flow. Custom environments contain specific methods that define the problem space of a task, such as the state and action spaces of the RL agent and the signal (or reward) that the RL algorithm will optimize over. By specifying a few methods within a custom environment, individuals can use Flow to design traffic control tasks of various types, such as optimal traffic light signal timing and flow regulation via mixed autonomy traffic (see the figures below). Finally, these environments are compatible with OpenAI Gym.
#
# The rest of the tutorial is organized as follows: in section 1 walks through the process of creating an environment for mixed autonomy vehicle control where the autonomous vehicles perceive all vehicles in the network, and section two implements the environment in simulation.
#
# <img src="img/sample_envs.png">
#
#
# ## 1. Creating an Environment Class
#
# In this tutorial we will create an environment in which the accelerations of a handful of vehicles in the network are specified by a single centralized agent, with the objective of the agent being to improve the average speed of all vehicle in the network. In order to create this environment, we begin by inheriting the base environment class located in *flow.envs*:

# %%
# import the base environment class
from flow.envs import Env

# define the environment class, and inherit properties from the base environment class
class myEnv(Env):
    pass

# %% [markdown]
# `Env` provides the interface for running and modifying a SUMO simulation. Using this class, we are able to start sumo, provide a network to specify a configuration and controllers, perform simulation steps, and reset the simulation to an initial configuration.
#
# By inheriting Flow's base environment, a custom environment for varying control tasks can be created by adding the following functions to the child class:
# * **action_space**
# * **observation_space**
# * **apply_rl_actions**
# * **get_state**
# * **compute_reward**
#
# Each of these components are covered in the next few subsections.
#
# ### 1.1 ADDITIONAL_ENV_PARAMS
#
# The features used to parametrize components of the state/action space as well as the reward function are specified within the `EnvParams` input, as discussed in tutorial 1. Specifically, for the sake of our environment, the `additional_params` attribute within `EnvParams` will be responsible for storing information on the maximum possible accelerations and decelerations by the autonomous vehicles in the network. Accordingly, for this problem, we define an `ADDITIONAL_ENV_PARAMS` variable of the form:

# %%
ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# %% [markdown]
# All environments presented in Flow provide a unique `ADDITIONAL_ENV_PARAMS` component containing the information needed to properly define some environment-specific parameters. We assume that these values are always provided by the user, and accordingly can be called from `env_params`. For example, if we would like to call the "max_accel" parameter, we simply type:
#
#     max_accel = env_params.additional_params["max_accel"]
#
# ### 1.2 action_space
#
# The `action_space` method defines the number and bounds of the actions provided by the RL agent. In order to define these bounds with an OpenAI gym setting, we use several objects located within *gym.spaces*. For instance, the `Box` object is used to define a bounded array of values in $\mathbb{R}^n$.

# %%
from gym.spaces.box import Box

# %% [markdown]
# In addition, `Tuple` objects (not used by this tutorial) allow users to combine multiple `Box` elements together.

# %%
from gym.spaces import Tuple

# %% [markdown]
# Once we have imported the above objects, we are ready to define the bounds of our action space. Given that our actions consist of a list of n real numbers (where n is the number of autonomous vehicles) bounded from above and below by "max_accel" and "max_decel" respectively (see section 1.1), we can define our action space as follows:

# %%
class myEnv(myEnv):

    @property
    def action_space(self):
        num_actions = self.initial_vehicles.num_rl_vehicles
        accel_ub = self.env_params.additional_params["max_accel"]
        accel_lb = - abs(self.env_params.additional_params["max_decel"])

        return Box(low=accel_lb,
                   high=accel_ub,
                   shape=(num_actions,))

# %% [markdown]
# ### 1.3 observation_space
# The observation space of an environment represents the number and types of observations that are provided to the reinforcement learning agent. For this example, we will be observe two values for each vehicle: its position and speed. Accordingly, we need a observation space that is twice the size of the number of vehicles in the network.

# %%
class myEnv(myEnv):  # update my environment class

    @property
    def observation_space(self):
        return Box(
            low=0,
            high=float("inf"),
            shape=(2*self.initial_vehicles.num_vehicles,),
        )

# %% [markdown]
# ### 1.4 apply_rl_actions
# The function `apply_rl_actions` is responsible for transforming commands specified by the RL agent into actual actions performed within the simulator. The vehicle kernel within the environment class contains several helper methods that may be of used to facilitate this process. These functions include:
# * **apply_acceleration** (list of str, list of float) -> None: converts an action, or a list of actions, into accelerations to the specified vehicles (in simulation)
# * **apply_lane_change** (list of str, list of {-1, 0, 1}) -> None: converts an action, or a list of actions, into lane change directions for the specified vehicles (in simulation)
# * **choose_route** (list of str, list of list of str) -> None: converts an action, or a list of actions, into rerouting commands for the specified vehicles (in simulation)
#
# For our example we consider a situation where the RL agent can only specify accelerations for the RL vehicles; accordingly, the actuation method for the RL agent is defined as follows:

# %%
class myEnv(myEnv):  # update my environment class

    def _apply_rl_actions(self, rl_actions):
        # the names of all autonomous (RL) vehicles in the network
        rl_ids = self.k.vehicle.get_rl_ids()

        # use the base environment method to convert actions into accelerations for the rl vehicles
        self.k.vehicle.apply_acceleration(rl_ids, rl_actions)

# %% [markdown]
# ### 1.5 get_state
#
# The `get_state` method extracts features from within the environments and provides then as inputs to the policy provided by the RL agent. Several helper methods exist within flow to help facilitate this process. Some useful helper method can be accessed from the following objects:
# * **self.k.vehicle**: provides current state information for all vehicles within the network
# * **self.k.traffic_light**: provides state information on the traffic lights
# * **self.k.network**: information on the network, which unlike the vehicles and traffic lights is static
# * More accessor objects and methods can be found within the Flow documentation at: http://berkeleyflow.readthedocs.io/en/latest/
#
# In order to model global observability within the network, our state space consists of the speeds and positions of all vehicles (as mentioned in section 1.3). This is implemented as follows:

# %%
import numpy as np

class myEnv(myEnv):  # update my environment class

    def get_state(self, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we use the get_absolute_position method to get the positions of all vehicles
        pos = [self.k.vehicle.get_x_by_id(veh_id) for veh_id in ids]

        # we use the get_speed method to get the velocities of all vehicles
        vel = [self.k.vehicle.get_speed(veh_id) for veh_id in ids]

        # the speeds and positions are concatenated to produce the state
        return np.concatenate((pos, vel))

# %% [markdown]
# ### 1.6 compute_reward
#
# The `compute_reward` method returns the reward associated with any given state. These value may encompass returns from values within the state space (defined in section 1.5) or may contain information provided by the environment but not immediately available within the state, as is the case in partially observable tasks (or POMDPs).
#
# For this tutorial, we choose the reward function to be the average speed of all vehicles currently in the network. In order to extract this information from the environment, we use the `get_speed` method within the Vehicle kernel class to collect the current speed of all vehicles in the network, and return the average of these speeds as the reward. This is done as follows:

# %%
import numpy as np

class myEnv(myEnv):  # update my environment class

    def compute_reward(self, rl_actions, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we next get a list of the speeds of all vehicles in the network
        speeds = self.k.vehicle.get_speed(ids)

        # finally, we return the average of all these speeds as the reward
        return np.mean(speeds)

# %% [markdown]
# ## 2. Testing the New Environment
#
#
# ### 2.1 Testing in Simulation
# Now that we have successfully created our new environment, we are ready to test this environment in simulation. We begin by running this environment in a non-RL based simulation. The return provided at the end of the simulation is indicative of the cumulative expected reward when jam-like behavior exists within the netowrk.

# %%
from flow.controllers import IDMController, ContinuousRouter
from flow.core.experiment import Experiment
from flow.core.params import SumoParams, EnvParams, \
    InitialConfig, NetParams
from flow.core.params import VehicleParams
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS

sim_params = SumoParams(sim_step=0.1, render=True)

vehicles = VehicleParams()
vehicles.add(veh_id="idm",
             acceleration_controller=(IDMController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=22)

env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS)

additional_net_params = ADDITIONAL_NET_PARAMS.copy()
net_params = NetParams(additional_params=additional_net_params)

initial_config = InitialConfig(bunching=20)

flow_params = dict(
    exp_tag='ring',
    env_name=myEnv,  # using my new environment for the simulation
    network=RingNetwork,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=initial_config,
)

# number of time steps
flow_params['env'].horizon = 1500
exp = Experiment(flow_params)

# run the sumo simulation
_ = exp.run(1)
# Out:
# Round 0, return: 4325.908541380999
# Average, std returns: 4325.908541380999, 0.0
# Average, std velocities: 2.883939027587335, 0.0
# Average, std outflows: 0.0, 0.0
# Total time: 10.2845139503479
# steps/second: 278.6972689035798

# %% [markdown]
# ### 2.2 Training the New Environment
#
# Next, we wish to train this environment in the presence of the autonomous vehicle agent to reduce the formation of waves in the network, thereby pushing the performance of vehicles in the network past the above expected return.
#
# The below code block may be used to train the above environment using the Proximal Policy Optimization (PPO) algorithm provided by RLlib. In order to register the environment with OpenAI gym, the environment must first be placed in a separate ".py" file and then imported via the script below. Then, the script immediately below should function regularly.

# %%
#############################################################
####### Replace this with the environment you created #######
#############################################################
from flow.envs import AccelEnv as myEnv

# %% [markdown]
# **Note**: We do not recommend training this environment to completion within a jupyter notebook setting; however, once training is complete, visualization of the resulting policy should show that the autonomous vehicle learns to dissipate the formation and propagation of waves in the network.

# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter


# time horizon of a single rollout
HORIZON = 1500
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 3

# We place one autonomous vehicle and 22 human-driven vehicles in the network
vehicles = VehicleParams()
vehicles.add(
    veh_id="human",
    acceleration_controller=(IDMController, {
        "noise": 0.2
    }),
    car_following_params=SumoCarFollowingParams(
        min_gap=0
    ),
    routing_controller=(ContinuousRouter, {}),
    num_vehicles=21)
vehicles.add(
    veh_id="rl",
    acceleration_controller=(RLController, {}),
    routing_controller=(ContinuousRouter, {}),
    num_vehicles=1)

flow_params = dict(
    # name of the experiment
    exp_tag="stabilizing_the_ring",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=RingNetwork,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=NetParams(
        additional_params=ADDITIONAL_NET_PARAMS.copy()
    ),

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=InitialConfig(
        bunching=20,
    ),
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config


alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1, num_gpus=1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-05-26 19:47:37,412	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-05-26_19-47-37_411861_7992/logs.
# 2020-05-26 19:47:37,523	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:36750 to respond...
# 2020-05-26 19:47:37,656	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:25305 to respond...
# 2020-05-26 19:47:37,662	INFO services.py:809 -- Starting Redis shard with 3.33 GB max memory.
# 2020-05-26 19:47:37,690	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-05-26_19-47-37_411861_7992/logs.
# 2020-05-26 19:47:37,691	WARNING services.py:1330 -- WARNING: The default object store size of 5.0 GB will use more than 50% of the available memory on this node (9.34 GB). Consider setting the object store memory manually to a smaller size to avoid memory contention with other applications.
# 2020-05-26 19:47:37,692	INFO services.py:1475 -- Starting the Plasma object store with 5.0 GB memory using /dev/shm.
# 2020-05-26 19:47:37,786	INFO trial_runner.py:176 -- Starting a new experiment.
# 2020-05-26 19:47:37,800	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-05-26 19:47:37,808	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs
# Memory usage on this node: 7.4/16.7 GB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/1 GPUs
# Memory usage on this node: 7.4/16.7 GB
# Result logdir: /home/roberto/ray_results/stabilizing_the_ring
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_AccelEnv-v0_0:	RUNNING
#
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8074)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8074) 2020-05-26 19:47:40,118	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=8074) 2020-05-26 19:47:41,231	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=8074) 2020-05-26 19:47:41.232340: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8074) 2020-05-26 19:47:41.234935: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8074) 2020-05-26 19:47:41.234969: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8074) 2020-05-26 19:47:41.234976: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8074) 2020-05-26 19:47:41.235039: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8074) 2020-05-26 19:47:41.235074: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8074) 2020-05-26 19:47:41.235081: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8074) 2020-05-26 19:47:41,332	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=8074)
# (pid=8074) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=8074)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=8074)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=8074)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=8074)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=8074)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 44) dtype=float32>,
# (pid=8074)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 44) dtype=float32>,
# (pid=8074)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=8074)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=8074)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=8074)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=8074)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=8074)
# (pid=8074) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8074)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8074) 2020-05-26 19:47:42,033	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7ff90f798a90>}
# (pid=8074) 2020-05-26 19:47:42,033	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7ff90f798748>}
# (pid=8074) 2020-05-26 19:47:42,119	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7ff90f7985f8>}
# (pid=8074) 2020-05-26 19:47:42,166	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8073)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8075)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8076)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8074) 2020-05-26 19:47:44,633	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=8075) 2020-05-26 19:47:45,427	INFO rollout_worker.py:319 -- Creating policy evaluation worker 3 on CPU (please ignore any CUDA init errors)
# (pid=8075) 2020-05-26 19:47:45.437265: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8075) 2020-05-26 19:47:45.438935: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8075) 2020-05-26 19:47:45.438956: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8075) 2020-05-26 19:47:45.438962: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8075) 2020-05-26 19:47:45.439013: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8075) 2020-05-26 19:47:45.439041: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8075) 2020-05-26 19:47:45.439047: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8073) 2020-05-26 19:47:45,532	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=8073) 2020-05-26 19:47:45.543053: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8073) 2020-05-26 19:47:45.544983: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8073) 2020-05-26 19:47:45.545022: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8073) 2020-05-26 19:47:45.545028: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8073) 2020-05-26 19:47:45.545089: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8073) 2020-05-26 19:47:45.545130: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8073) 2020-05-26 19:47:45.545136: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8076) 2020-05-26 19:47:45,547	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=8076) 2020-05-26 19:47:45.557823: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8076) 2020-05-26 19:47:45.559666: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8076) 2020-05-26 19:47:45.559700: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8076) 2020-05-26 19:47:45.559706: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8076) 2020-05-26 19:47:45.559768: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8076) 2020-05-26 19:47:45.559797: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8076) 2020-05-26 19:47:45.559803: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8076) 2020-05-26 19:47:45,661	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=8076)
# (pid=8076) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=8076)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=8076)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=8076)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=8076)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=8076)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 44) dtype=float32>,
# (pid=8076)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 44) dtype=float32>,
# (pid=8076)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=8076)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=8076)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=8076)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=8076)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=8076)
# (pid=8075) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8075)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8073) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8073)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8076) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8076)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8076) 2020-05-26 19:47:46,420	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=8076) 2020-05-26 19:47:49,240	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((44,), dtype=float64, min=0.0, max=0.96, mean=0.318)}}
# (pid=8076) 2020-05-26 19:47:49,240	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=8076) 2020-05-26 19:47:49,240	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((44,), dtype=float64, min=0.0, max=0.96, mean=0.318)
# (pid=8076) 2020-05-26 19:47:49,241	INFO sampler.py:407 -- Filtered obs: np.ndarray((44,), dtype=float64, min=0.0, max=0.96, mean=0.318)
# (pid=8076) 2020-05-26 19:47:49,241	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=8076)
# (pid=8076) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=8076)                                   'env_id': 0,
# (pid=8076)                                   'info': None,
# (pid=8076)                                   'obs': np.ndarray((44,), dtype=float64, min=0.0, max=0.96, mean=0.318),
# (pid=8076)                                   'prev_action': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=8076)                                   'prev_reward': 0.0,
# (pid=8076)                                   'rnn_state': []},
# (pid=8076)                         'type': 'PolicyEvalData'}]}
# (pid=8076)
# (pid=8076) 2020-05-26 19:47:49,241	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=8076) 2020-05-26 19:47:49,270	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=8076)
# (pid=8076) { 'default_policy': ( np.ndarray((1, 1), dtype=float32, min=0.812, max=0.812, mean=0.812),
# (pid=8076)                       [],
# (pid=8076)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.287, max=0.287, mean=0.287),
# (pid=8076)                         'behaviour_logits': np.ndarray((1, 2), dtype=float32, min=0.001, max=0.003, mean=0.002),
# (pid=8076)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.002, max=0.002, mean=0.002)})}
# (pid=8076)
# (pid=8076) 2020-05-26 19:47:50,383	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=8076)
# (pid=8076) { 'agent0': { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.013, max=0.398, mean=0.277),
# (pid=8076)                         'actions': np.ndarray((200, 1), dtype=float32, min=-2.618, max=2.644, mean=0.082),
# (pid=8076)                         'advantages': np.ndarray((200,), dtype=float32, min=0.092, max=4.198, mean=2.602),
# (pid=8076)                         'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8076)                         'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.0, max=0.006, mean=0.003),
# (pid=8076)                         'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=8076)                         'eps_id': np.ndarray((200,), dtype=int64, min=1382834736.0, max=1382834736.0, mean=1382834736.0),
# (pid=8076)                         'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=8076)                         'new_obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.311),
# (pid=8076)                         'obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.311),
# (pid=8076)                         'prev_actions': np.ndarray((200, 1), dtype=float32, min=-2.618, max=2.644, mean=0.082),
# (pid=8076)                         'prev_rewards': np.ndarray((200,), dtype=float32, min=0.0, max=0.14, mean=0.1),
# (pid=8076)                         'rewards': np.ndarray((200,), dtype=float32, min=0.069, max=0.14, mean=0.101),
# (pid=8076)                         't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=8076)                         'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8076)                         'value_targets': np.ndarray((200,), dtype=float32, min=0.091, max=4.2, mean=2.601),
# (pid=8076)                         'vf_preds': np.ndarray((200,), dtype=float32, min=-0.002, max=0.002, mean=-0.0)},
# (pid=8076)               'type': 'SampleBatch'}}
# (pid=8076)
# (pid=8076) 2020-05-26 19:47:50,385	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=8076)
# (pid=8076) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.013, max=0.398, mean=0.277),
# (pid=8076)             'actions': np.ndarray((200, 1), dtype=float32, min=-2.618, max=2.644, mean=0.082),
# (pid=8076)             'advantages': np.ndarray((200,), dtype=float32, min=0.092, max=4.198, mean=2.602),
# (pid=8076)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8076)             'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.0, max=0.006, mean=0.003),
# (pid=8076)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=8076)             'eps_id': np.ndarray((200,), dtype=int64, min=1382834736.0, max=1382834736.0, mean=1382834736.0),
# (pid=8076)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=8076)             'new_obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.311),
# (pid=8076)             'obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.311),
# (pid=8076)             'prev_actions': np.ndarray((200, 1), dtype=float32, min=-2.618, max=2.644, mean=0.082),
# (pid=8076)             'prev_rewards': np.ndarray((200,), dtype=float32, min=0.0, max=0.14, mean=0.1),
# (pid=8076)             'rewards': np.ndarray((200,), dtype=float32, min=0.069, max=0.14, mean=0.101),
# (pid=8076)             't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=8076)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8076)             'value_targets': np.ndarray((200,), dtype=float32, min=0.091, max=4.2, mean=2.601),
# (pid=8076)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.002, max=0.002, mean=-0.0)},
# (pid=8076)   'type': 'SampleBatch'}
# (pid=8076)
# 2020-05-26 19:47:57,735	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=8074, host=kleine-kuchen)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=8075, host=kleine-kuchen)
#   File "/home/roberto/flow/flow/envs/base.py", line 505, in reset
#     speed=speed)
#   File "/home/roberto/flow/flow/core/kernel/vehicle/traci.py", line 1110, in add
#     departSpeed=str(speed))
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/traci/_vehicle.py", line 1427, in add
#     self._connection._sendExact()
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 106, in _sendExact
#     raise TraCIException(err, prefix[1], _RESULTS[prefix[2]])
# traci.exceptions.TraCIException: Invalid departLane definition for vehicle 'human_0';
#  must be one of ("random", "free", "allowed", "best", "first", or an int>=0)
#
# During handling of the above exception, another exception occurred:
#
# ray_RolloutWorker:sample() (pid=8075, host=kleine-kuchen)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 313, in _env_runner
#     soft_horizon)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 473, in _process_observations
#     resetted_obs = base_env.try_reset(env_id)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 336, in try_reset
#     return {_DUMMY_AGENT_ID: self.vector_env.reset_at(env_id)}
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 104, in reset_at
#     return self.envs[index].reset()
#   File "/home/roberto/flow/flow/envs/ring/accel.py", line 177, in reset
#     obs = super().reset()
#   File "/home/roberto/flow/flow/envs/base.py", line 511, in reset
#     self.k.kernel_api.vehicle.remove(veh_id)  # FIXME: hack
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/traci/_vehicle.py", line 1435, in remove
#     tc.CMD_SET_VEHICLE_VARIABLE, tc.REMOVE, vehID, reason)
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 143, in _sendByteCmd
#     self._sendExact()
#   File "/home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 106, in _sendExact
#     raise TraCIException(err, prefix[1], _RESULTS[prefix[2]])
# traci.exceptions.TraCIException: Vehicle 'human_0' is not known
#
#
# 2020-05-26 19:47:57,739	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-05-26 19:47:57,743	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# (pid=8074) 2020-05-26 19:47:57,733	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=8075) Error: Answered with error to command 0xc4: Invalid departLane definition for vehicle 'human_0';
# (pid=8075)  must be one of ("random", "free", "allowed", "best", "first", or an int>=0)
# (pid=8075) Error: Answered with error to command 0xc4: Vehicle 'human_0' is not known
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/1 GPUs
# Memory usage on this node: 8.4/16.7 GB
# Result logdir: /home/roberto/ray_results/stabilizing_the_ring
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_AccelEnv-v0_0:	RUNNING, 1 failures: /home/roberto/ray_results/stabilizing_the_ring/PPO_AccelEnv-v0_0_2020-05-26_19-47-37awkd5xl0/error_2020-05-26_19-47-57.txt
#
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8361)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8361) 2020-05-26 19:48:00,436	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=8361) 2020-05-26 19:48:01,520	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=8361) 2020-05-26 19:48:01.521584: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8361) 2020-05-26 19:48:01.523880: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8361) 2020-05-26 19:48:01.523925: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8361) 2020-05-26 19:48:01.523932: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8361) 2020-05-26 19:48:01.523996: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8361) 2020-05-26 19:48:01.524033: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8361) 2020-05-26 19:48:01.524048: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8361) 2020-05-26 19:48:01,616	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=8361)
# (pid=8361) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=8361)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=8361)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=8361)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=8361)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=8361)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 44) dtype=float32>,
# (pid=8361)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 44) dtype=float32>,
# (pid=8361)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=8361)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=8361)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=8361)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=8361)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=8361)
# (pid=8361) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8361)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8361) 2020-05-26 19:48:02,263	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f99ad4d6668>}
# (pid=8361) 2020-05-26 19:48:02,263	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f99ad4d6320>}
# (pid=8361) 2020-05-26 19:48:02,263	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f99ad4d61d0>}
# (pid=8361) 2020-05-26 19:48:02,299	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8417)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8416)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8415)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8427) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8427)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8423) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8423)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=8424) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=8424)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=8361) 2020-05-26 19:48:05,362	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=8417) 2020-05-26 19:48:06,467	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=8417) 2020-05-26 19:48:06.476288: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8417) 2020-05-26 19:48:06.478775: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8417) 2020-05-26 19:48:06.478803: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8417) 2020-05-26 19:48:06.478811: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8417) 2020-05-26 19:48:06.478865: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8417) 2020-05-26 19:48:06.478891: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8417) 2020-05-26 19:48:06.478898: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8416) 2020-05-26 19:48:06,456	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=8416) 2020-05-26 19:48:06.466602: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8416) 2020-05-26 19:48:06.469163: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8416) 2020-05-26 19:48:06.469191: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8416) 2020-05-26 19:48:06.469200: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8416) 2020-05-26 19:48:06.469253: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8416) 2020-05-26 19:48:06.469278: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8416) 2020-05-26 19:48:06.469285: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8416) 2020-05-26 19:48:06,560	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=8416)
# (pid=8416) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=8416)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=8416)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=8416)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=8416)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=8416)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 44) dtype=float32>,
# (pid=8416)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 44) dtype=float32>,
# (pid=8416)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=8416)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=8416)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=8416)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=8416)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=8416)
# (pid=8415) 2020-05-26 19:48:06,575	INFO rollout_worker.py:319 -- Creating policy evaluation worker 3 on CPU (please ignore any CUDA init errors)
# (pid=8415) 2020-05-26 19:48:06.585350: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=8415) 2020-05-26 19:48:06.587959: E tensorflow/stream_executor/cuda/cuda_driver.cc:397] failed call to cuInit: CUDA_ERROR_NO_DEVICE
# (pid=8415) 2020-05-26 19:48:06.587992: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:158] retrieving CUDA diagnostic information for host: kleine-kuchen
# (pid=8415) 2020-05-26 19:48:06.587999: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:165] hostname: kleine-kuchen
# (pid=8415) 2020-05-26 19:48:06.588083: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:189] libcuda reported version is: 430.50.0
# (pid=8415) 2020-05-26 19:48:06.588114: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:193] kernel reported version is: 430.50.0
# (pid=8415) 2020-05-26 19:48:06.588120: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:300] kernel version seems to match DSO: 430.50.0
# (pid=8416) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8416)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8417) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8417)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8415) /home/roberto/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8415)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8416) 2020-05-26 19:48:07,339	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=8416) 2020-05-26 19:48:09,983	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((44,), dtype=float64, min=0.015, max=0.971, mean=0.322)}}
# (pid=8416) 2020-05-26 19:48:09,983	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=8416) 2020-05-26 19:48:09,983	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((44,), dtype=float64, min=0.015, max=0.971, mean=0.322)
# (pid=8416) 2020-05-26 19:48:09,983	INFO sampler.py:407 -- Filtered obs: np.ndarray((44,), dtype=float64, min=0.015, max=0.971, mean=0.322)
# (pid=8416) 2020-05-26 19:48:09,984	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=8416)
# (pid=8416) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=8416)                                   'env_id': 0,
# (pid=8416)                                   'info': None,
# (pid=8416)                                   'obs': np.ndarray((44,), dtype=float64, min=0.015, max=0.971, mean=0.322),
# (pid=8416)                                   'prev_action': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=8416)                                   'prev_reward': 0.0,
# (pid=8416)                                   'rnn_state': []},
# (pid=8416)                         'type': 'PolicyEvalData'}]}
# (pid=8416)
# (pid=8416) 2020-05-26 19:48:09,984	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=8416) 2020-05-26 19:48:10,013	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=8416)
# (pid=8416) { 'default_policy': ( np.ndarray((1, 1), dtype=float32, min=-1.646, max=-1.646, mean=-1.646),
# (pid=8416)                       [],
# (pid=8416)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.102, max=0.102, mean=0.102),
# (pid=8416)                         'behaviour_logits': np.ndarray((1, 2), dtype=float32, min=0.001, max=0.004, mean=0.002),
# (pid=8416)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.002, max=0.002, mean=0.002)})}
# (pid=8416)
# (pid=8416) 2020-05-26 19:48:11,095	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=8416)
# (pid=8416) { 'agent0': { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.017, max=0.4, mean=0.282),
# (pid=8416)                         'actions': np.ndarray((200, 1), dtype=float32, min=-2.404, max=2.523, mean=0.066),
# (pid=8416)                         'advantages': np.ndarray((200,), dtype=float32, min=0.077, max=4.513, mean=2.623),
# (pid=8416)                         'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8416)                         'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.003, max=0.004, mean=0.001),
# (pid=8416)                         'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=8416)                         'eps_id': np.ndarray((200,), dtype=int64, min=1405212567.0, max=1405212567.0, mean=1405212567.0),
# (pid=8416)                         'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=8416)                         'new_obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.316),
# (pid=8416)                         'obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.316),
# (pid=8416)                         'prev_actions': np.ndarray((200, 1), dtype=float32, min=-2.404, max=2.523, mean=0.069),
# (pid=8416)                         'prev_rewards': np.ndarray((200,), dtype=float32, min=0.0, max=0.152, mean=0.103),
# (pid=8416)                         'rewards': np.ndarray((200,), dtype=float32, min=0.065, max=0.152, mean=0.103),
# (pid=8416)                         't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=8416)                         'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8416)                         'value_targets': np.ndarray((200,), dtype=float32, min=0.074, max=4.515, mean=2.624),
# (pid=8416)                         'vf_preds': np.ndarray((200,), dtype=float32, min=-0.003, max=0.002, mean=0.0)},
# (pid=8416)               'type': 'SampleBatch'}}
# (pid=8416)
# (pid=8416) 2020-05-26 19:48:11,097	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=8416)
# (pid=8416) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.017, max=0.4, mean=0.282),
# (pid=8416)             'actions': np.ndarray((200, 1), dtype=float32, min=-2.404, max=2.523, mean=0.066),
# (pid=8416)             'advantages': np.ndarray((200,), dtype=float32, min=0.077, max=4.513, mean=2.623),
# (pid=8416)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8416)             'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.003, max=0.004, mean=0.001),
# (pid=8416)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=8416)             'eps_id': np.ndarray((200,), dtype=int64, min=1405212567.0, max=1405212567.0, mean=1405212567.0),
# (pid=8416)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=8416)             'new_obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.316),
# (pid=8416)             'obs': np.ndarray((200, 44), dtype=float32, min=0.0, max=1.0, mean=0.316),
# (pid=8416)             'prev_actions': np.ndarray((200, 1), dtype=float32, min=-2.404, max=2.523, mean=0.069),
# (pid=8416)             'prev_rewards': np.ndarray((200,), dtype=float32, min=0.0, max=0.152, mean=0.103),
# (pid=8416)             'rewards': np.ndarray((200,), dtype=float32, min=0.065, max=0.152, mean=0.103),
# (pid=8416)             't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=8416)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=8416)             'value_targets': np.ndarray((200,), dtype=float32, min=0.074, max=4.515, mean=2.624),
# (pid=8416)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.003, max=0.002, mean=0.0)},
# (pid=8416)   'type': 'SampleBatch'}
# (pid=8416)
